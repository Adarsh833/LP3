# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
df = pd.read_csv('Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
plt.xlabel('Exited')
plt.ylabel('Count')
df['Exited'].value_counts().plot.bar()
plt.show()

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df = pd.concat([df,pd.get_dummies(df['Geography'],prefix='Geo')],axis=1)

# %%
df = pd.concat([df,pd.get_dummies(df['Gender'])],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
#  14  Geo_France       10000 non-null  bool
#  15  Geo_Germany      10000 non-null  bool
#  16  Geo_Spain        10000 non-null  bool
#  17  Female           10000 non-null  bool
#  18  Male             10000 non-null  bool
# dtypes: bool(5), float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.drop(columns=['RowNumber','CustomerId','Surname','Geography','Gender'],inplace=True)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geo_France  Geo_Germany  \
# 0               1        101348.88       1        True        False
# 1               1        112542.58       0       False        False
# 2               0        113931.57       1        True        False
# 3               0         93826.63       0        True        False
# 4               1         79084.10       0       False        False
#
#    Geo_Spain  Female   Male
# 0      False    True  False
# 1       True    True  False
# 2      False    True  False
# 3      False    True  False
# 4       True    True  False

# %% [markdown]
# ### Splitting Data

# %%
y = df['Exited'].values
x = df.loc[:,df.columns != 'Exited'].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=20,test_size=0.25)

# %% [markdown]
# ### Scaling Data

# %%
from sklearn.preprocessing import StandardScaler
std_x = StandardScaler()
x_train = std_x.fit_transform(x_train)
x_test = std_x.transform(x_test)

# %%
x_train.shape
# Out:
# (7500, 13)

# %% [markdown]
# ### Tensorflow Model - Neural Network Classifier

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense,Conv1D,Flatten
from tensorflow.keras.models import Sequential, Model

# %%
model=Sequential()
model.add(Flatten(input_shape=(13,)))
model.add(Dense(100,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',metrics=['accuracy'],loss='BinaryCrossentropy')

# %%
model.fit(x_train,y_train,batch_size=64,validation_split=0.1,epochs=100)
# Out:
# Epoch 1/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7582 - loss: 0.5484 - val_accuracy: 0.8267 - val_loss: 0.4233
# Epoch 2/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8072 - loss: 0.4328 - val_accuracy: 0.8373 - val_loss: 0.4020
# Epoch 3/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8225 - loss: 0.4128 - val_accuracy: 0.8400 - val_loss: 0.3835
# Epoch 4/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8396 - loss: 0.3929 - val_accuracy: 0.8547 - val_loss: 0.3623
# Epoch 5/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8399 - loss: 0.3817 - val_accuracy: 0.8627 - val_loss: 0.3488
# Epoch 6/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8433 - loss: 0.3729 - val_accuracy: 0.8693 - val_loss: 0.3361
# Epoch 7/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8519 - loss: 0.3527 - val_accuracy: 0.8653 - val_loss: 0.3329
# Epoch 8/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8525 - loss: 0.3524 - val_accuracy: 0.8707 - val_loss: 0.3259
# Epoch 9/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8581 - loss: 0.3474 - val_accuracy: 0.8693 - val_loss: 0.3258
# Epoch 10/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8498 - loss: 0.3612 - val_accuracy: 0.8787 - val_loss: 0.3191
# Epoch 11/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8545 - loss: 0.3473 - val_accuracy: 0.8773 - val_loss: 0.3179
# Epoch 12/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8554 - loss: 0.3435 - val_accuracy: 0.8813 - val_loss: 0.3170
# Epoch 13/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8461 - loss: 0.3542 - val_accuracy: 0.8800 - val_loss: 0.3214
# Epoch 14/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8574 - loss: 0.3392 - val_accuracy: 0.8707 - val_loss: 0.3164
# Epoch 15/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8684 - loss: 0.3261 - val_accuracy: 0.8827 - val_loss: 0.3187
# Epoch 16/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8589 - loss: 0.3499 - val_accuracy: 0.8787 - val_loss: 0.3139
# Epoch 17/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8579 - loss: 0.3410 - val_accuracy: 0.8800 - val_loss: 0.3130
# Epoch 18/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8602 - loss: 0.3366 - val_accuracy: 0.8787 - val_loss: 0.3193
# Epoch 19/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8622 - loss: 0.3390 - val_accuracy: 0.8747 - val_loss: 0.3142
# Epoch 20/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8628 - loss: 0.3362 - val_accuracy: 0.8760 - val_loss: 0.3150
# Epoch 21/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8575 - loss: 0.3394 - val_accuracy: 0.8773 - val_loss: 0.3132
# Epoch 22/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8662 - loss: 0.3286 - val_accuracy: 0.8773 - val_loss: 0.3149
# Epoch 23/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8654 - loss: 0.3296 - val_accuracy: 0.8773 - val_loss: 0.3198
# Epoch 24/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8649 - loss: 0.3286 - val_accuracy: 0.8853 - val_loss: 0.3195
# Epoch 25/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8581 - loss: 0.3387 - val_accuracy: 0.8800 - val_loss: 0.3110
# Epoch 26/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8555 - loss: 0.3441 - val_accuracy: 0.8813 - val_loss: 0.3136
# Epoch 27/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8664 - loss: 0.3247 - val_accuracy: 0.8787 - val_loss: 0.3166
# Epoch 28/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8573 - loss: 0.3340 - val_accuracy: 0.8813 - val_loss: 0.3122
# Epoch 29/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8678 - loss: 0.3295 - val_accuracy: 0.8840 - val_loss: 0.3086
# Epoch 30/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8607 - loss: 0.3342 - val_accuracy: 0.8827 - val_loss: 0.3124
# Epoch 31/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8616 - loss: 0.3338 - val_accuracy: 0.8787 - val_loss: 0.3141
# Epoch 32/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8660 - loss: 0.3198 - val_accuracy: 0.8787 - val_loss: 0.3193
# Epoch 33/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8599 - loss: 0.3336 - val_accuracy: 0.8800 - val_loss: 0.3108
# Epoch 34/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8713 - loss: 0.3159 - val_accuracy: 0.8800 - val_loss: 0.3135
# Epoch 35/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8640 - loss: 0.3324 - val_accuracy: 0.8747 - val_loss: 0.3180
# Epoch 36/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8646 - loss: 0.3298 - val_accuracy: 0.8813 - val_loss: 0.3183
# Epoch 37/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8625 - loss: 0.3292 - val_accuracy: 0.8800 - val_loss: 0.3167
# Epoch 38/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8703 - loss: 0.3140 - val_accuracy: 0.8773 - val_loss: 0.3183
# Epoch 39/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8628 - loss: 0.3299 - val_accuracy: 0.8800 - val_loss: 0.3126
# Epoch 40/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8678 - loss: 0.3229 - val_accuracy: 0.8707 - val_loss: 0.3132
# Epoch 41/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8643 - loss: 0.3244 - val_accuracy: 0.8720 - val_loss: 0.3203
# Epoch 42/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8615 - loss: 0.3363 - val_accuracy: 0.8720 - val_loss: 0.3123
# Epoch 43/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8657 - loss: 0.3290 - val_accuracy: 0.8787 - val_loss: 0.3091
# Epoch 44/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8644 - loss: 0.3276 - val_accuracy: 0.8800 - val_loss: 0.3161
# Epoch 45/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8698 - loss: 0.3254 - val_accuracy: 0.8747 - val_loss: 0.3189
# Epoch 46/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8637 - loss: 0.3324 - val_accuracy: 0.8760 - val_loss: 0.3146
# Epoch 47/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8639 - loss: 0.3246 - val_accuracy: 0.8667 - val_loss: 0.3193
# Epoch 48/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8708 - loss: 0.3228 - val_accuracy: 0.8693 - val_loss: 0.3186
# Epoch 49/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8644 - loss: 0.3231 - val_accuracy: 0.8693 - val_loss: 0.3188
# Epoch 50/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8723 - loss: 0.3147 - val_accuracy: 0.8760 - val_loss: 0.3126
# Epoch 51/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.3197 - val_accuracy: 0.8667 - val_loss: 0.3181
# Epoch 52/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8636 - loss: 0.3405 - val_accuracy: 0.8773 - val_loss: 0.3130
# Epoch 53/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8723 - loss: 0.3187 - val_accuracy: 0.8787 - val_loss: 0.3136
# Epoch 54/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8617 - loss: 0.3287 - val_accuracy: 0.8720 - val_loss: 0.3239
# Epoch 55/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8625 - loss: 0.3304 - val_accuracy: 0.8720 - val_loss: 0.3132
# Epoch 56/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8694 - loss: 0.3174 - val_accuracy: 0.8653 - val_loss: 0.3194
# Epoch 57/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8640 - loss: 0.3288 - val_accuracy: 0.8773 - val_loss: 0.3161
# Epoch 58/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8698 - loss: 0.3155 - val_accuracy: 0.8760 - val_loss: 0.3199
# Epoch 59/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8685 - loss: 0.3291 - val_accuracy: 0.8707 - val_loss: 0.3171
# Epoch 60/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8675 - loss: 0.3206 - val_accuracy: 0.8760 - val_loss: 0.3147
# Epoch 61/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.3216 - val_accuracy: 0.8707 - val_loss: 0.3161
# Epoch 62/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8649 - loss: 0.3217 - val_accuracy: 0.8667 - val_loss: 0.3146
# Epoch 63/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8704 - loss: 0.3164 - val_accuracy: 0.8653 - val_loss: 0.3195
# Epoch 64/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8731 - loss: 0.3089 - val_accuracy: 0.8747 - val_loss: 0.3194
# Epoch 65/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8717 - loss: 0.3158 - val_accuracy: 0.8667 - val_loss: 0.3160
# Epoch 66/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8739 - loss: 0.3176 - val_accuracy: 0.8787 - val_loss: 0.3162
# Epoch 67/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8723 - loss: 0.3114 - val_accuracy: 0.8733 - val_loss: 0.3154
# Epoch 68/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8708 - loss: 0.3159 - val_accuracy: 0.8747 - val_loss: 0.3160
# Epoch 69/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8720 - loss: 0.3103 - val_accuracy: 0.8747 - val_loss: 0.3157
# Epoch 70/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8700 - loss: 0.3198 - val_accuracy: 0.8733 - val_loss: 0.3182
# Epoch 71/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8685 - loss: 0.3152 - val_accuracy: 0.8693 - val_loss: 0.3168
# Epoch 72/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8691 - loss: 0.3287 - val_accuracy: 0.8733 - val_loss: 0.3182
# Epoch 73/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8672 - loss: 0.3211 - val_accuracy: 0.8720 - val_loss: 0.3168
# Epoch 74/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8650 - loss: 0.3260 - val_accuracy: 0.8680 - val_loss: 0.3190
# Epoch 75/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8693 - loss: 0.3155 - val_accuracy: 0.8813 - val_loss: 0.3187
# Epoch 76/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8705 - loss: 0.3129 - val_accuracy: 0.8773 - val_loss: 0.3179
# Epoch 77/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8678 - loss: 0.3225 - val_accuracy: 0.8640 - val_loss: 0.3201
# Epoch 78/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8743 - loss: 0.3098 - val_accuracy: 0.8813 - val_loss: 0.3157
# Epoch 79/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8661 - loss: 0.3269 - val_accuracy: 0.8760 - val_loss: 0.3174
# Epoch 80/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8727 - loss: 0.3120 - val_accuracy: 0.8693 - val_loss: 0.3168
# Epoch 81/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8738 - loss: 0.3074 - val_accuracy: 0.8720 - val_loss: 0.3190
# Epoch 82/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8626 - loss: 0.3191 - val_accuracy: 0.8760 - val_loss: 0.3135
# Epoch 83/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8771 - loss: 0.3041 - val_accuracy: 0.8773 - val_loss: 0.3193
# Epoch 84/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8689 - loss: 0.3099 - val_accuracy: 0.8773 - val_loss: 0.3170
# Epoch 85/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8691 - loss: 0.3170 - val_accuracy: 0.8720 - val_loss: 0.3219
# Epoch 86/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8713 - loss: 0.3096 - val_accuracy: 0.8693 - val_loss: 0.3153
# Epoch 87/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8695 - loss: 0.3153 - val_accuracy: 0.8747 - val_loss: 0.3153
# Epoch 88/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8802 - loss: 0.3026 - val_accuracy: 0.8667 - val_loss: 0.3223
# Epoch 89/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8676 - loss: 0.3197 - val_accuracy: 0.8680 - val_loss: 0.3188
# Epoch 90/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8731 - loss: 0.3067 - val_accuracy: 0.8707 - val_loss: 0.3237
# Epoch 91/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8725 - loss: 0.3091 - val_accuracy: 0.8800 - val_loss: 0.3194
# Epoch 92/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8790 - loss: 0.3050 - val_accuracy: 0.8693 - val_loss: 0.3236
# Epoch 93/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8735 - loss: 0.3166 - val_accuracy: 0.8747 - val_loss: 0.3169
# Epoch 94/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8754 - loss: 0.3061 - val_accuracy: 0.8733 - val_loss: 0.3150
# Epoch 95/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8823 - loss: 0.3000 - val_accuracy: 0.8747 - val_loss: 0.3249
# Epoch 96/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8739 - loss: 0.3019 - val_accuracy: 0.8720 - val_loss: 0.3206
# Epoch 97/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8769 - loss: 0.3106 - val_accuracy: 0.8680 - val_loss: 0.3230
# Epoch 98/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8695 - loss: 0.3052 - val_accuracy: 0.8680 - val_loss: 0.3189
# Epoch 99/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8773 - loss: 0.3005 - val_accuracy: 0.8600 - val_loss: 0.3251
# Epoch 100/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8632 - loss: 0.3101 - val_accuracy: 0.8733 - val_loss: 0.3186

# %%
pred = model.predict(x_test)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred = []
for val in pred:
    if val > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8604

# %%
cm = confusion_matrix(y_test,y_pred)
display = ConfusionMatrixDisplay(cm)
display.plot()
